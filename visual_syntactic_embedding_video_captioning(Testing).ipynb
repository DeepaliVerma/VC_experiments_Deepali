# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaliVerma/VC_experiments_Deepali/blob/main/visual_syntactic_embedding_video_captioning(Testing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/DACNet/
# Out:
# /content/drive/MyDrive/DACNet

# %%
# !git clone --recursive https://github.com/jssprz/visual_syntactic_embedding_video_captioning.git
# Out:
# Cloning into 'visual_syntactic_embedding_video_captioning'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 98 (delta 51), reused 59 (delta 26), pack-reused 0
# Unpacking objects: 100% (98/98), done.
# Submodule 'video_description_eval' (https://github.com/jssprz/video_description_eval.git) registered for path 'video_description_eval'
# Cloning into '/content/drive/My Drive/DACNet/visual_syntactic_embedding_video_captioning/video_description_eval'...
# remote: Enumerating objects: 794, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 794 (delta 3), reused 9 (delta 2), pack-reused 781
# Receiving objects: 100% (794/794), 130.05 MiB | 15.89 MiB/s, done.
# Resolving deltas: 100% (416/416), done.
# Submodule path 'video_description_eval': checked out '29dcb608b2adbaa2107118d2c452a57183750d77'

# %%
cd visual_syntactic_embedding_video_captioning/
# Out:
# /content/drive/My Drive/DACNet/visual_syntactic_embedding_video_captioning

# %% [markdown]
# #Training
# dataset download

# %%
# !mkdir -p data/MSVD && wget -i msvd_data.txt -P data/MSVD
# Out:
# --2021-10-24 20:55:39--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/val_references.txt
# Resolving s06.imfd.cl (s06.imfd.cl)... 192.80.24.186
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172602 (169K) [text/plain]
# Saving to: ‘data/MSVD/val_references.txt’
#
# val_references.txt  100%[===================>] 168.56K   704KB/s    in 0.2s
#
# 2021-10-24 20:55:40 (704 KB/s) - ‘data/MSVD/val_references.txt’ saved [172602/172602]
#
# --2021-10-24 20:55:40--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/test_references.txt
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1116532 (1.1M) [text/plain]
# Saving to: ‘data/MSVD/test_references.txt’
#
# test_references.txt 100%[===================>]   1.06M  4.33MB/s    in 0.2s
#
# 2021-10-24 20:55:41 (4.33 MB/s) - ‘data/MSVD/test_references.txt’ saved [1116532/1116532]
#
# --2021-10-24 20:55:41--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/config.ini
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 847 [application/octet-stream]
# Saving to: ‘data/MSVD/config.ini’
#
# config.ini          100%[===================>]     847  --.-KB/s    in 0s
#
# 2021-10-24 20:55:41 (59.5 MB/s) - ‘data/MSVD/config.ini’ saved [847/847]
#
# --2021-10-24 20:55:41--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/corpus.pkl
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17445053 (17M) [application/octet-stream]
# Saving to: ‘data/MSVD/corpus.pkl’
#
# corpus.pkl          100%[===================>]  16.64M  5.56MB/s    in 3.0s
#
# 2021-10-24 20:55:44 (5.56 MB/s) - ‘data/MSVD/corpus.pkl’ saved [17445053/17445053]
#
# --2021-10-24 20:55:44--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/resnext_eco.npy
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 28242048 (27M) [application/octet-stream]
# Saving to: ‘data/MSVD/resnext_eco.npy’
#
# resnext_eco.npy     100%[===================>]  26.93M  2.27MB/s    in 9.3s
#
# 2021-10-24 20:55:53 (2.90 MB/s) - ‘data/MSVD/resnext_eco.npy’ saved [28242048/28242048]
#
# --2021-10-24 20:55:53--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/tag_feats.npy
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2364128 (2.3M) [application/octet-stream]
# Saving to: ‘data/MSVD/tag_feats.npy’
#
# tag_feats.npy       100%[===================>]   2.25M  2.41MB/s    in 0.9s
#
# 2021-10-24 20:55:55 (2.41 MB/s) - ‘data/MSVD/tag_feats.npy’ saved [2364128/2364128]
#
# --2021-10-24 20:55:55--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/linspace16_20_resnext101_r1plus2d18-eco_globals.h5
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1001105952 (955M) [application/octet-stream]
# Saving to: ‘data/MSVD/linspace16_20_resnext101_r1plus2d18-eco_globals.h5’
#
# linspace16_20_resne 100%[===================>] 954.73M  6.25MB/s    in 2m 48s
#
# 2021-10-24 20:58:43 (5.68 MB/s) - ‘data/MSVD/linspace16_20_resnext101_r1plus2d18-eco_globals.h5’ saved [1001105952/1001105952]
#
# FINISHED --2021-10-24 20:58:43--
# Total wall clock time: 3m 3s
# Downloaded: 7 files, 1002M in 3m 2s (5.51 MB/s)

# %%
# !mkdir -p data/MSR-VTT && wget -i msrvtt_data.txt -P data/MSR-VTT
# Out:
# --2021-10-24 21:11:54--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/val_references.txt
# Resolving s06.imfd.cl (s06.imfd.cl)... 192.80.24.186
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 531244 (519K) [text/plain]
# Saving to: ‘data/MSR-VTT/val_references.txt’
#
# val_references.txt  100%[===================>] 518.79K  1.05MB/s    in 0.5s
#
# 2021-10-24 21:11:56 (1.05 MB/s) - ‘data/MSR-VTT/val_references.txt’ saved [531244/531244]
#
# --2021-10-24 21:11:56--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/test_references.txt
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235065 (3.1M) [text/plain]
# Saving to: ‘data/MSR-VTT/test_references.txt’
#
# test_references.txt 100%[===================>]   3.08M  4.15MB/s    in 0.7s
#
# 2021-10-24 21:11:56 (4.15 MB/s) - ‘data/MSR-VTT/test_references.txt’ saved [3235065/3235065]
#
# --2021-10-24 21:11:56--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/config.ini
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 880 [application/octet-stream]
# Saving to: ‘data/MSR-VTT/config.ini’
#
# config.ini          100%[===================>]     880  --.-KB/s    in 0s
#
# 2021-10-24 21:11:57 (29.0 MB/s) - ‘data/MSR-VTT/config.ini’ saved [880/880]
#
# --2021-10-24 21:11:57--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/corpus.pkl
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23921595 (23M) [application/octet-stream]
# Saving to: ‘data/MSR-VTT/corpus.pkl’
#
# corpus.pkl          100%[===================>]  22.81M  3.18MB/s    in 6.8s
#
# 2021-10-24 21:12:03 (3.35 MB/s) - ‘data/MSR-VTT/corpus.pkl’ saved [23921595/23921595]
#
# --2021-10-24 21:12:03--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/resnext_eco.npy
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143360128 (137M) [application/octet-stream]
# Saving to: ‘data/MSR-VTT/resnext_eco.npy’
#
# resnext_eco.npy     100%[===================>] 136.72M  8.07MB/s    in 32s
#
# 2021-10-24 21:12:36 (4.25 MB/s) - ‘data/MSR-VTT/resnext_eco.npy’ saved [143360128/143360128]
#
# --2021-10-24 21:12:36--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/tag_feats.npy
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12000128 (11M) [application/octet-stream]
# Saving to: ‘data/MSR-VTT/tag_feats.npy’
#
# tag_feats.npy       100%[===================>]  11.44M  3.37MB/s    in 3.4s
#
# 2021-10-24 21:12:39 (3.36 MB/s) - ‘data/MSR-VTT/tag_feats.npy’ saved [12000128/12000128]
#
# --2021-10-24 21:12:39--  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Reusing existing connection to s06.imfd.cl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7523286200 (7.0G) [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  14%[=>                  ]   1.01G  5.12MB/s    in 5m 55s
#
# 2021-10-24 21:18:35 (2.90 MB/s) - Connection closed at byte 1080852219. Retrying.
#
# --2021-10-24 21:18:36--  (try: 2)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 6442433981 (6.0G) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  28%[++==>               ]   2.01G  2.37MB/s    in 6m 43s
#
# 2021-10-24 21:25:19 (2.56 MB/s) - Connection closed at byte 2161737576. Retrying.
#
# --2021-10-24 21:25:21--  (try: 3)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 5361548624 (5.0G) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  43%[+++++==>            ]   3.02G  4.48MB/s    in 5m 13s
#
# 2021-10-24 21:30:35 (3.30 MB/s) - Connection closed at byte 3244118717. Retrying.
#
# --2021-10-24 21:30:38--  (try: 4)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 4279167483 (4.0G) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  57%[++++++++==>         ]   4.03G  4.13MB/s    in 3m 34s
#
# 2021-10-24 21:34:13 (4.82 MB/s) - Connection closed at byte 4326378226. Retrying.
#
# --2021-10-24 21:34:17--  (try: 5)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 3196907974 (3.0G) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  71%[+++++++++++==>      ]   5.04G  5.33MB/s    in 3m 39s
#
# 2021-10-24 21:37:57 (4.71 MB/s) - Connection closed at byte 5408695655. Retrying.
#
# --2021-10-24 21:38:02--  (try: 6)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 2114590545 (2.0G) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne  86%[++++++++++++++==>   ]   6.04G  5.11MB/s    in 4m 0s
#
# 2021-10-24 21:42:03 (4.31 MB/s) - Connection closed at byte 6491502508. Retrying.
#
# --2021-10-24 21:42:09--  (try: 7)  https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 7523286200 (7.0G), 1031783692 (984M) remaining [application/octet-stream]
# Saving to: ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’
#
# linspace16_30_resne 100%[+++++++++++++++++==>]   7.01G  6.26MB/s    in 3m 12s
#
# 2021-10-24 21:45:22 (5.11 MB/s) - ‘data/MSR-VTT/linspace16_30_resnext101_r1plus2d18-c3d_features-cnn_sem_globals-eco_globals.h5’ saved [7523286200/7523286200]
#
# FINISHED --2021-10-24 21:45:22--
# Total wall clock time: 33m 28s
# Downloaded: 7 files, 1.1G in 33m 0s (599 KB/s)

# %% [markdown]
# #Testing Phrase
# checkpoint downloads

# %%
# !wget https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/captioning_chkpt_41.pt -P pretrain/MSVD
# !wget https://s06.imfd.cl/04/github-data/SemSynAN/MSR-VTT/captioning_chkpt_12.pt -P pretrain/MSR-VTT
# Out:
# --2021-10-24 21:45:22--  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/captioning_chkpt_41.pt
# Resolving s06.imfd.cl (s06.imfd.cl)... 192.80.24.186
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2044279575 (1.9G) [application/octet-stream]
# Saving to: ‘pretrain/MSVD/captioning_chkpt_41.pt’
#
# captioning_chkpt_41  53%[=========>          ]   1.01G  7.15MB/s    in 3m 45s
#
# 2021-10-24 21:49:09 (4.59 MB/s) - Connection closed at byte 1083677148. Retrying.
#
# --2021-10-24 21:49:10--  (try: 2)  https://s06.imfd.cl/04/github-data/SemSynAN/MSVD/captioning_chkpt_41.pt
# Connecting to s06.imfd.cl (s06.imfd.cl)|192.80.24.186|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 2044279575 (1.9G), 960602427 (916M) remaining [application/octet-stream]
# Saving to: ‘pretrain/MSVD/captioning_chkpt_41.pt’
#
# captioning_chkpt_41 100%[++++++++++=========>]   1.90G  11.9MB/s    in 2m 40s
#
# 2021-10-24 21:51:51 (5.71 MB/s) - ‘pretrain/MSVD/captioning_chkpt_41.pt’ saved [2044279575/2044279575]

# %%
# !python test.py -chckpt pretrain/MSVD/captioning_chkpt_41.pt -data data/MSVD/ -out results/MSVD/
# Out:
# Size of vocabulary: 12594
# loading visual feats...
# visual feats loaded
# tcmalloc: large alloc 1552588800 bytes == 0x55e35e678000 @  0x7fd5a7944b6b 0x7fd5a7964379 0x7fd4fde3426e 0x7fd4fde359e2 0x7fd500061d43 0x7fd4ff526d6d 0x7fd5000072e4 0x7fd4ff5a7229 0x7fd4ff5a7a55 0x7fd4ffcf5da2 0x7fd4ff898f92 0x7fd4ff5afd7b 0x7fd4ffdeb812 0x7fd4ffc28084 0x7fd50137b417 0x7fd50137bac5 0x7fd4ff8984e2 0x7fd5a29f79fe 0x55e215d6e544 0x55e215d6e240 0x55e215de2627 0x55e215ddcced 0x55e215d6fbda 0x55e215dde737 0x55e215ddc9ee 0x55e215d7048c 0x55e215d70698 0x55e215ddefe4 0x55e215ddc9ee 0x55e215d7048c 0x55e215db3409
# tensor(17.9959) a monkey is playing with a dog
# tensor(17.4930) a man is riding on a motorcycle
# tensor(16.6047) a cat is cleaning its face
# tensor(17.4172) a man is talking
# tensor(16.1260) a cat is playing a rope
# tensor(17.6545) a man is cutting a
# tensor(17.1951) a woman is putting a
# tensor(17.8804) the boys are dancing
# tensor(18.6009) a woman is talking
# tensor(16.9872) a woman is putting on makeup
# tensor(18.4656) a cat is playing
# tensor(18.5144) a man is dancing
# tensor(17.4806) a woman is a woman
# tensor(16.1284) a woman is doing on a rope
# tensor(18.5185) a dog is running
# tensor(17.7111) a man is cutting a
# tensor(16.2545) a woman is doing a woman
# tensor(16.8887) a man is walking on a house
# tensor(17.3541) a man is running a car
# tensor(17.9721) two people are talking
# tensor(18.6465) a man is playing a guitar
# tensor(16.2438) a man is slicing a potato
# tensor(18.4006) a man is playing a guitar
# tensor(17.7375) a dog is playing with a toy
# tensor(17.1022) a man is driving a car
# tensor(17.5096) a man is pushing a car
# tensor(16.7941) a dog is swimming
# tensor(14.9675) a man is mixing flour
# tensor(16.2202) a badger is running
# tensor(18.5348) a man is talking
# tensor(17.5456) a man is playing a ball
# tensor(17.6590) two boys are fighting
# tensor(17.1130) a man is playing a ball
# tensor(17.2266) a man is slicing a
# tensor(16.4811) a baby is walking
# tensor(16.7086) a polar bear is walking on the snow
# tensor(16.7048) a polar bear is walking on the snow
# tensor(17.9365) a man is playing a guitar
# tensor(17.9897) a man is eating
# tensor(18.4522) a cat is running
# tensor(16.6322) a man is shooting a gun
# tensor(16.1418) a man is spreading butter on a bread
# tensor(15.8111) a man is taking a
# tensor(16.7530) a man is removing a
# tensor(15.6174) a man is eating
# tensor(17.2140) a car is driving a car
# tensor(17.3112) a man is doing exercise
# tensor(12.2399) a cat is water
# tensor(14.9026) a man is using a
# tensor(15.6854) a woman is cutting a piece of a piece of a
# tensor(16.5961) a group of people are dancing
# tensor(17.3511) a monkey is eating food
# tensor(18.3185) a boy is playing a
# tensor(17.6580) a man is playing a guitar
# tensor(18.1565) a girl is riding a horse
# tensor(18.2923) a man is talking on a stage
# tensor(17.6888) a car is driving a car
# tensor(16.9173) a man is playing with a ball
# tensor(18.9194) a dog is playing
# tensor(17.0652) a dog is swimming in a pool
# tensor(17.6459) a man is putting a microwave
# tensor(16.6760) a man is shooting with a gun
# tensor(17.2724) a person is petting a small loris
# tensor(18.1811) a man is running
# tensor(17.6969) people are dancing
# tensor(17.5943) a baby is walking
# tensor(17.3924) a girl is dancing
# tensor(18.0935) a man is talking
# tensor(17.8701) a person is playing with a
# tensor(13.8513) a man is filling water
# tensor(18.8681) a woman is dancing
# tensor(17.6640) a man is running a car
# tensor(17.0018) a woman is talking on a phone
# tensor(16.1761) a man is pouring oil into a pot
# tensor(16.3465) a man is pouring some sauce into a pot
# tensor(16.4169) a man is pouring sauce into a pot
# tensor(16.3015) a man is pouring sauce into a pot
# tensor(15.9468) a man is pouring pasta into a bowl
# tensor(15.7927) a man is pouring sauce on a pot
# tensor(17.8413) a man is eating food
# tensor(17.5810) a man is eating food
# tensor(17.9364) three people are dancing
# tensor(17.7213) a woman is swimming
# tensor(14.0696) a person is eating
# tensor(16.8557) a young man is dancing
# tensor(17.1679) a man is playing soccer
# tensor(17.1107) a monkey is doing karate
# tensor(18.7657) a man is playing
# tensor(18.0612) a baby is laughing
# tensor(17.8427) a dog is playing with a ball
# tensor(14.4808) a woman is washing a pitcher
# tensor(16.9912) a person is playing with a small animal
# tensor(16.6024) a man is running
# tensor(16.1871) a cat is playing with a small animal
# tensor(17.4014) a man is playing a piano
# tensor(16.6800) a man is playing basketball
# tensor(17.4174) a man is doing a
# tensor(19.2534) a man is eating
# tensor(17.0602) a panda is playing with a
# tensor(18.5284) a man is playing a guitar
# tensor(17.6534) a woman is riding a horse
# tensor(17.0416) a boy is playing a piano
# tensor(18.5106) a woman is a woman
# tensor(17.0610) a man is playing a ball
# tensor(15.3862) a man is pouring a
# tensor(17.4141) a dog is playing a
# tensor(17.1922) a cat is eating a
# tensor(18.0585) a man is fighting
# tensor(17.5125) a woman is applying makeup
# tensor(17.1757) a woman is slicing a potato
# tensor(15.9845) a train is running on the track
# tensor(18.3232) a man is drinking
# tensor(16.3506) a baby is playing with a baby
# tensor(16.9153) a tiger is running
# tensor(17.4185) a car is driving a car
# tensor(17.4489) a cat is playing with a
# tensor(17.7202) a man is riding a
# tensor(16.5857) a baby is eating
# tensor(17.8585) a man is dancing on a stage
# tensor(15.2809) a man is peeling a apple
# tensor(16.5576) a man is cooking
# tensor(17.4208) a cat is playing with a
# tensor(17.4150) a person is drawing on a paper
# tensor(17.5691) a woman is dancing
# tensor(17.6190) a woman is dancing
# tensor(16.0012) a woman is pouring oil into a pan
# tensor(17.1737) a man is riding a bicycle
# tensor(16.8490) a woman is cooking
# tensor(16.5997) a man is slicing a loaf
# tensor(15.6425) a man is slicing a tomato
# tensor(14.3589) a person is tearing a paper
# tensor(17.3312) a panda is playing
# tensor(17.6127) a panda is playing
# tensor(17.7495) a man is playing a piano
# tensor(16.1204) a badger is walking
# tensor(15.2253) a group of a walking
# tensor(15.9482) a man is rolling a dough
# tensor(18.7165) a dog is playing
# tensor(18.1114) a man is playing a guitar
# tensor(18.0946) two people are playing
# tensor(16.4416) a man is cutting a
# tensor(17.0061) a man is cooking
# tensor(18.0015) a man is playing
# tensor(15.2424) a woman is filling a pitcher
# tensor(16.0995) a person is mixing dough
# tensor(16.4623) a baby is eating
# tensor(17.0234) a man is doing a car
# tensor(18.8752) a dog is playing
# tensor(18.4639) a man is a baby
# tensor(17.5018) a man is walking in a store
# tensor(17.3878) a man is shooting
# tensor(16.8591) a man is doing on a
# tensor(17.4162) two men are doing
# tensor(16.6982) a man is running down a road
# tensor(17.5703) a man is playing basketball
# tensor(17.1129) a badger is running
# tensor(16.8708) a man is jumping
# tensor(16.5304) a man is cooking
# tensor(16.7066) a man is making a
# tensor(17.8771) a man is playing a guitar
# tensor(17.3807) a dog is playing with a ball
# tensor(17.3237) a little boy is playing with a ball
# tensor(16.4210) a man is doing a bike on a motorcycle
# tensor(16.3776) a dog is swimming
# tensor(17.5132) a band is performing on stage
# tensor(17.9928) two boys are playing
# tensor(16.8170) a man is shooting a gun
# tensor(16.7793) a man is chopping some onions
# tensor(16.8994) a man is peeling a potato
# tensor(16.8701) a man is chopping garlic
# tensor(18.5004) a woman is dancing
# tensor(17.0305) a man is slicing an onion
# tensor(17.5290) a baby is playing a
# tensor(17.3949) a man is doing a
# tensor(18.2895) a dog is eating
# tensor(17.9423) a woman is dancing
# tensor(16.3144) a car is running down a track
# tensor(16.6356) a woman is peeling shrimp
# tensor(16.7011) a woman is peeling shrimp
# tensor(16.8965) a woman is cutting a fish
# tensor(16.8850) a woman is cutting a fish
# tensor(16.5211) a woman is putting a fish
# tensor(16.8405) a woman is slicing a carrot
# tensor(16.7917) a person is cutting a fish
# tensor(17.1079) a woman is mixing some rice
# tensor(16.4992) a woman is putting meat in a bowl
# tensor(16.0909) a person is putting some meat into a pot
# tensor(15.9268) a person is boiling some shrimp
# tensor(16.8176) a woman is cutting a
# tensor(16.6521) a woman is frying some meat
# tensor(16.7933) a woman is cutting a
# tensor(17.1087) a woman is cooking
# tensor(15.4395) a woman is cutting a piece of a piece of a
# tensor(16.5086) a woman is slicing a piece of tofu
# tensor(15.3662) a woman is slicing a piece of a piece of a
# tensor(17.3289) a woman is peeling a potato
# tensor(17.1354) a woman is pouring ingredients into a bowl
# tensor(16.5342) a person is cutting a piece of meat
# tensor(16.7198) a woman is cutting a piece of meat
# tensor(17.3181) a woman is cooking
# tensor(17.1714) a man is riding a woman
# tensor(18.2171) a man is playing a guitar
# tensor(17.3146) a woman is slicing a
# tensor(16.8923) a woman is cutting meat
# tensor(15.9601) a woman is seasoning a piece of meat
# tensor(15.1860) a woman is putting meat on a piece of meat
# tensor(15.7559) a person is making a piece of meat
# tensor(16.3048) a woman is frying some meat
# tensor(17.6391) a man is riding a motorcycle
# tensor(15.8251) a man is pouring a liquid into a bowl
# tensor(16.3407) a man is slicing a
# tensor(16.4152) a man is cutting a tomato
# tensor(17.2799) a man is drinking
# tensor(17.4744) a man is a car
# tensor(17.0085) a woman is holding a woman s hand
# tensor(18.0327) a man is playing a guitar
# tensor(17.9840) a dog is playing with a
# tensor(17.7925) a monkey is walking on the ground
# tensor(17.1754) a man is riding a bicycle
# tensor(17.3793) a woman is sitting on a bed
# tensor(17.6376) a woman is sitting on a bed
# tensor(17.2299) a man is doing a
# tensor(16.9822) a man is doing exercise
# tensor(17.6608) a woman is riding a horse
# tensor(17.6153) a cat is playing with a toy
# tensor(17.8188) two men are fighting
# tensor(16.7773) a man is playing a
# tensor(18.2975) a man is playing a guitar
# tensor(17.8693) a man is singing
# tensor(16.1688) a man is cutting meat
# tensor(16.7302) a man is playing with a ball
# tensor(16.5790) a man jumps into a pool
# tensor(17.8828) a man is holding a man
# tensor(15.1164) a man is pouring some sauce on a bowl
# tensor(16.7359) a man is mixing a
# tensor(14.3108) a man is putting a tortilla on a plastic
# tensor(17.1525) a man is shooting a gun
# tensor(18.5381) a monkey is eating
# tensor(17.6185) a group of people are dancing
# tensor(17.2683) a baby is walking
# tensor(18.0615) a girl is riding a small
# tensor(14.9493) a girl is washing a pitcher
# tensor(18.0499) a girl is jumping on a rope
# tensor(18.4883) a man is playing a guitar
# tensor(16.5633) a group of a animal is running
# tensor(13.4081) a man is using a camera
# tensor(16.9878) a man is cutting a potato
# tensor(16.6993) a man is chopping an onion
# tensor(15.9596) a woman is peeling a potato
# tensor(16.8805) a man is chopping garlic
# tensor(16.5849) a man is slicing a tomato
# tensor(16.1258) a man is slicing a pepper
# tensor(16.7254) a man is cutting an onion
# tensor(16.5411) a person is peeling an onion
# tensor(16.9011) a man is slicing a potato
# tensor(15.5910) a woman is climbing a
# tensor(17.8109) a woman is talking on a phone
# tensor(15.1135) a woman is pouring water into a bowl
# tensor(17.0528) a soccer player is playing
# tensor(17.0279) a polar bear is walking on the snow
# tensor(16.7923) a man is peeling a potato
# tensor(16.5243) a man is slicing a potato
# tensor(16.2078) a cat is playing with a bowl
# tensor(18.8102) a baby is playing
# tensor(18.5879) a baby is playing
# tensor(18.1984) a man is playing a guitar
# tensor(16.2940) a group of a dog
# tensor(16.3422) a man is cooking
# tensor(17.5040) a person is cutting a
# tensor(17.2604) a group of zebras are walking
# tensor(16.5944) two people are a woman
# tensor(17.4344) a man is running on a road
# tensor(17.8391) a man is riding a bike
# tensor(17.4514) a man is riding a bike
# tensor(17.0350) a man is peeling a potato
# tensor(16.8029) the men are running
# tensor(11.9734) a dog is taking a water
# tensor(17.2254) a man is doing tricks
# tensor(17.7304) a woman is playing a violin
# tensor(17.4441) a man is playing a guitar
# tensor(18.0920) a man is a car
# tensor(17.9160) a man is doing on a
# tensor(14.8165) a man is peeling a
# tensor(17.1803) a man is riding a snow
# tensor(16.2097) a man is mixing a pot of a
# tensor(18.7764) a monkey is eating
# tensor(18.6062) a woman is holding a woman
# tensor(17.2661) a woman is singing on a stage
# tensor(17.9757) a dog is playing with a ball
# tensor(17.0522) a boy is playing a
# tensor(18.1443) a boy is playing with a ball
# tensor(17.1906) a cat is playing
# tensor(17.0839) a baby is playing with a baby
# tensor(17.0920) a person is playing with a small animal
# tensor(18.3160) a dog is playing
# tensor(15.3949) a man is mixing a bowl of a bowl of a
# tensor(16.2652) a man is cutting meat
# tensor(16.3840) a man is cutting meat
# tensor(16.1650) a man is cutting a piece of meat
# tensor(17.9210) two men are fighting
# tensor(17.7482) a man is flying
# tensor(18.4580) a boy is running
# tensor(18.3384) two men are dancing
# tensor(17.1219) a woman is talking on a phone
# tensor(16.4976) a man is cutting a potato
# tensor(17.5260) a baby is eating
# tensor(17.0365) a man is drawing a paper
# tensor(18.1494) a man is riding a bicycle
# tensor(18.1917) a man is playing
# tensor(18.3745) a woman is eating
# tensor(18.2292) two girls are dancing
# tensor(17.3452) a man is riding a bike
# tensor(14.3907) a man is tearing a paper
# tensor(16.0497) a woman is pouring oil into a bowl
# tensor(17.0836) a man is slicing bread
# tensor(16.5353) a man is slicing an onion
# tensor(16.5722) a man is cooking
# tensor(17.4716) a dog is playing with a dog
# tensor(18.1000) a dog is running on a dog
# tensor(17.5260) a man is shooting a gun
# tensor(17.2948) a man is cutting a paper
# tensor(13.8209) a man is eating
# tensor(17.3150) a man is riding a bike
# tensor(17.3361) a man is riding a bike
# tensor(16.8395) a woman is swimming in a pool
# tensor(16.6281) a man is slicing an onion
# tensor(16.6105) a man is slicing an onion
# tensor(17.6678) a woman is doing a woman
# tensor(17.4595) a man is riding a bicycle
# tensor(18.1139) a woman is playing a guitar
# tensor(17.0369) a woman is applying makeup
# tensor(17.1059) a man is climbing a
# tensor(18.3081) a boy is riding a bicycle
# tensor(17.2178) a baby is eating
# tensor(16.8987) a group of people are dancing
# tensor(16.4523) a man is pouring sauce into a pot
# tensor(15.6730) a man is pouring a pot of rice into a pot
# tensor(16.7509) a man is pouring sauce into a pot
# tensor(16.9240) two men are fighting
# tensor(16.9951) a man is talking
# tensor(17.8476) a woman is riding a horse
# tensor(18.5351) a man is riding a horse
# tensor(17.2238) a girl is playing in the beach
# tensor(18.0066) a man is singing
# tensor(15.2670) a man is cutting a piece of a piece of a
# tensor(17.3683) a cat is eating a
# tensor(17.6992) a man is driving a car
# tensor(17.3109) a woman is putting her face
# tensor(17.3746) a group of walking
# tensor(16.8378) a baby is walking on a hallway
# tensor(18.2768) a woman is riding a horse
# tensor(17.6592) a baby is playing
# tensor(18.4960) a baby is eating
# tensor(18.2350) a dog is playing with a
# tensor(17.9087) a man is riding a bicycle
# tensor(17.8131) a dog is sitting on the floor
# tensor(15.8362) a man is cutting a piece of meat
# tensor(17.9678) a man is a woman
# tensor(17.4146) a man is playing a ball
# tensor(17.7914) three women are dancing
# tensor(16.4222) a man is jumping over a fence
# tensor(18.4703) a woman is cleaning a
# tensor(16.7328) a woman is woman on a woman
# tensor(13.9663) a man is cooking
# tensor(15.7651) a man is peeling a potato
# tensor(15.5726) a man is peeling a potato
# tensor(16.3579) a man is slicing a potato
# tensor(15.6761) a baby is playing a baby
# tensor(17.9183) a man is playing a keyboard
# tensor(16.1270) a man is mixing a
# tensor(17.3793) a man is riding a skateboard
# tensor(17.0875) a girl is riding a tricycle
# tensor(16.8333) a man is playing a flute
# tensor(15.5727) a group of a group of an field
# tensor(17.6279) two children are walking
# tensor(18.7348) a boy is talking
# tensor(18.2535) a boy is dancing
# tensor(17.1155) a panda is playing
# tensor(16.6385) a soccer player is a goal
# tensor(17.1791) a man and woman are kissing
# tensor(18.2819) a man is talking
# tensor(18.5649) a man is talking
# tensor(18.0891) a baby is eating
# tensor(16.9600) a cat is playing a
# tensor(18.1874) a man is dancing
# tensor(17.3250) a woman is riding a woman
# tensor(17.2527) a boy is playing with a ball
# tensor(17.4462) a boy is playing with a ball
# tensor(17.3162) a man is playing a ball
# tensor(14.9999) a woman is pouring ingredients into a bowl
# tensor(17.3436) two men are fighting
# tensor(18.2878) a baby is singing
# tensor(17.8984) a man is running on a road
# tensor(17.9474) men are playing
# tensor(15.9514) a man is mixing a
# tensor(17.1806) a puppy is playing with a toy
# tensor(17.0220) a dog is running on a field
# tensor(18.0108) a cat is licking a
# tensor(16.3923) a man is putting some sauce in a bowl
# tensor(16.3804) a person is mixing ingredients in a bowl
# tensor(17.0661) a woman is cooking
# tensor(16.6128) a person is cooking
# tensor(15.8065) a woman is cutting a fish
# tensor(16.5969) a person is cutting a fish
# tensor(17.3516) a woman is slicing a potato
# tensor(17.1304) a person is cutting a
# tensor(16.6217) a man is pushing a car
# tensor(17.3088) a man is breaking a sword
# tensor(18.1147) a woman is doing her hair
# tensor(17.6565) a dog is swimming
# tensor(17.2471) a man is lifting a car
# tensor(17.3303) a man is lifting a car
# tensor(17.0797) a monkey is chasing a
# tensor(18.4539) a man is playing with a
# tensor(17.9356) a baby is eating
# tensor(17.1741) a woman is applying makeup
# tensor(17.0641) a woman is carrying a woman
# tensor(16.7065) a panda is playing
# tensor(16.2495) a man is talking to a boy
# tensor(17.5244) a man is eating
# tensor(17.4950) a man is riding a bike
# tensor(16.3622) a person is cutting a piece of meat
# tensor(16.4861) a boy is playing a car
# tensor(17.5161) a man is playing with a ball
# tensor(16.8524) a man is running on the road
# tensor(18.7704) a man is talking
# tensor(17.4228) a man is cleaning a bag
# tensor(17.1541) a man is shooting
# tensor(17.5491) two kids are dancing
# tensor(17.7406) a woman is doing exercise
# tensor(17.9351) a boy is walking
# tensor(18.1686) a man is dancing
# tensor(18.0172) a man is moving
# tensor(18.6517) a girl is playing a guitar
# tensor(17.8096) a man is singing
# tensor(17.4922) two men are eating
# tensor(18.3333) a woman is dancing
# tensor(16.8789) a man and woman are walking
# tensor(18.4556) a man is playing with a
# tensor(17.1960) a man is running
# tensor(18.0398) a man is riding a bike
# tensor(16.3046) a woman is putting chicken
# tensor(15.7861) a man is seasoning some meat
# tensor(17.3436) a man is playing the piano
# tensor(18.5345) a man is a
# tensor(17.0658) a man is cutting meat
# tensor(18.8464) a woman is doing
# tensor(18.3264) a woman is doing
# tensor(17.4851) a man is talking
# tensor(16.7360) a group of people are running
# tensor(16.6292) a woman is peeling a potato
# tensor(16.5493) a person is cutting a potato
# tensor(17.0478) a man is lifting a car
# tensor(16.5617) a group of people are running
# tensor(17.6435) a man is teaching a
# tensor(18.3252) a person is cutting a paper
# tensor(16.7439) a woman is eating a
# tensor(18.1016) a woman is dancing
# tensor(17.8714) a woman is dancing
# tensor(16.5701) a baby is walking
# tensor(17.3512) a car is driving a car
# tensor(16.5986) a train is running
# tensor(18.5790) a man is putting a man
# tensor(17.3670) people are dancing
# tensor(17.6245) a man is drawing a paper
# tensor(17.0421) a man is a man
# tensor(17.6053) a man is doing a
# tensor(17.9060) a woman is a woman
# tensor(18.5080) a woman is talking
# tensor(15.5226) a man is stirring a bowl
# tensor(17.1977) a tiger is walking
# tensor(16.9101) a woman is slicing a potato
# tensor(17.6120) a baby is eating
# tensor(17.6695) a man is speaking
# tensor(16.6307) a man is slicing a carrot
# tensor(18.3360) a woman is dancing
# tensor(16.6833) a man is a man
# tensor(18.3617) a cat is playing
# tensor(15.5111) a man is stirring a pot of a bowl
# tensor(17.1276) a monkey is pulling a dog
# tensor(17.7081) a badger is eating
# tensor(17.6128) a man is talking
# tensor(17.4831) a baby is walking
# tensor(17.4794) a man is doing a
# tensor(16.2541) a woman is applying makeup on her hair
# tensor(15.5050) a woman is washing a
# tensor(16.7045) a man is slicing a tomato
# tensor(18.3665) a boy is playing a guitar
# tensor(12.8243) a man is eating
# tensor(18.5015) a man is playing a guitar
# tensor(18.2649) a boy is running
# tensor(17.5808) a dog is driving a car
# tensor(18.8643) a dog is walking
# tensor(16.2504) a man is pouring sauce into a bowl
# tensor(17.7146) a man is doing
# tensor(18.2949) a man is playing a guitar
# tensor(18.1035) a baby is playing
# tensor(17.3403) a woman is talking on a woman
# tensor(17.7156) a dog is playing with a puppy
# tensor(16.4457) the racers are running
# tensor(17.8721) a woman is riding a horse
# tensor(17.4501) a man is cooking
# tensor(17.7938) a man is doing in a
# tensor(18.0760) a man is a woman
# tensor(16.9955) a man is carrying a gun
# tensor(17.0235) a man is doing a
# tensor(17.5298) a monkey is walking
# tensor(17.3803) a man is pushing a car
# tensor(18.0259) a woman is carrying a woman
# tensor(17.3625) a person is playing with a toad
# tensor(17.7438) a man is riding a bike
# tensor(17.7213) a man is riding a bike
# tensor(17.7262) a car is driving
# tensor(17.4898) a man is riding a bike
# tensor(16.2455) a group of zebras are walking
# tensor(18.0519) a baby is swimming
# tensor(16.9863) a panda is playing
# tensor(14.3795) a bird is eating a bowl of water
# tensor(17.6952) two men are talking
# tensor(16.6347) a man is jumping on a rope
# tensor(17.0475) a man is cutting a tree
# tensor(17.9444) a cat is playing
# tensor(17.5679) a man is playing a piano
# tensor(16.1638) a man is cutting a piece of bread
# tensor(17.2404) a dog is playing with a dog
# tensor(16.5552) a man is running a car
# tensor(16.6059) a person is cooking meat
# tensor(17.4676) a man is making a bed
# tensor(17.5704) a woman is washing a woman
# tensor(17.8900) a woman is riding a woman
# tensor(17.4786) a man is riding a horse
# tensor(17.3336) a group of people are dancing
# tensor(17.2353) a group of men are playing
# tensor(17.1265) a boy is playing a piano
# tensor(16.8658) a panda is playing with a
# tensor(15.9545) a man is tearing a paper
# tensor(17.8993) three girls are dancing
# tensor(18.4620) a person is playing with a
# tensor(17.9386) a man is playing a guitar
# tensor(17.1483) a woman is dancing on a rope
# tensor(16.9193) a man is slicing a potato
# tensor(17.7012) a man is riding a bike
# tensor(17.3074) a man is shooting a gun
# tensor(16.4231) a cat is jumping into a bag
# tensor(16.9235) a group of zebras are playing
# tensor(17.6440) a man is a man
# tensor(17.8927) a train is running
# tensor(16.9944) a plane is taking off
# tensor(17.1954) a man is slicing a
# tensor(17.7264) a man is doing exercise
# tensor(17.2523) a man is riding a horse
# tensor(17.5963) a man is a man
# tensor(17.6092) a man is flying
# tensor(18.5124) a baby is eating
# tensor(16.6745) a man is cutting a
# tensor(17.5487) a man is drinking
# tensor(16.8058) a woman is applying makeup
# tensor(18.2284) a girl is playing a guitar
# tensor(17.9835) a girl is playing a guitar
# tensor(16.6784) a man is pushing a car
# tensor(18.2804) a baby is jumping
# tensor(17.5650) a girl is playing a violin
# tensor(17.9594) a monkey is eating
# tensor(15.5023) a woman is cutting a
# tensor(16.8425) a baby is playing with a baby
# tensor(16.5018) a man is swimming in water
# tensor(17.1114) a man is riding a woman
# tensor(17.1146) a man is playing basketball
# tensor(16.9708) a woman is doing a woman
# tensor(18.0851) a woman is riding a horse
# tensor(17.5663) a man is riding a skateboard
# tensor(18.2751) a man is a
# tensor(18.1130) a man is cutting a
# tensor(18.2807) a baby is dancing
# tensor(18.2070) a person is drawing
# tensor(16.5156) a woman is slicing a
# tensor(17.6916) a woman is doing a girl
# tensor(17.0422) a boy is running
# tensor(17.5810) a woman is doing a
# tensor(17.8245) a woman is a woman
# tensor(16.9267) a man is holding a man
# tensor(15.8643) a badger is walking on the forest
# tensor(18.0168) a man is playing
# tensor(15.4861) a cat is jumping on a cat
# tensor(17.3951) a man is cutting a grass
# tensor(16.2648) a car is going in the water
# tensor(17.1464) a man is running a ball
# tensor(17.6554) a boy is playing a
# tensor(18.0223) a man is playing a guitar
# tensor(16.9935) a woman is slicing a potato
# tensor(15.4398) a person is mixing eggs
# tensor(16.5929) a man is pushing a car
# tensor(18.2509) a woman is talking a woman
# tensor(17.2933) a man is running
# tensor(17.8217) a man is breaking a
# tensor(17.2860) a man is breaking a man
# tensor(16.3520) a man is doing a man
# tensor(18.2345) a man is dancing
# tensor(16.4826) a man is breaking a man
# tensor(17.0983) a man is running
# tensor(17.3687) a man is doing
# tensor(16.8411) a man is doing a man
# tensor(16.8443) a man is doing exercise
# tensor(17.0561) a man is doing exercise
# tensor(16.6496) a man is doing a
# tensor(16.8558) a man is doing exercise
# tensor(18.0798) a man is playing a
# tensor(16.9777) a man is cutting meat
# tensor(18.1545) a baby is playing
# tensor(16.7674) a man is a pizza
# tensor(19.1673) a cat is playing
# tensor(16.0128) a woman is putting some meat in a bowl
# tensor(17.2136) a group of women are fighting
# tensor(17.3441) a baby is walking in a
# tensor(17.8268) a dog is playing
# tensor(17.3156) a man is running a car
# tensor(16.6066) a woman is cutting a potato
# tensor(17.5701) a man is riding a horse
# tensor(17.5322) a dog is walking
# tensor(17.1497) a dog is playing with a
# tensor(17.4028) a man is talking on a street
# tensor(17.5731) a man is jumping
# tensor(17.1521) a dog is playing with a dog
# tensor(18.6171) a man is talking
# tensor(16.4424) a panda is climbing down
# tensor(17.6923) a woman is dancing
# tensor(15.8234) a man is walking down a boy
# tensor(10.3512) a squirrel is running
# tensor(16.3532) a man is slicing a carrot
# tensor(15.5982) a man is putting some vegetables into a pan
# tensor(16.1015) a man is cutting a carrot
# tensor(17.7031) a baby is playing with a toy
# tensor(16.1688) a man is making a
# tensor(18.2555) a man is playing a flute
# tensor(17.1895) a man is kicking a soccer ball
# tensor(16.7990) a person is cutting a piece of paper
# tensor(17.3701) a group of girls are dancing
# tensor(17.3550) a dog is playing with a toy
# tensor(16.3816) a person is drawing on a paper
# tensor(18.3897) a man is playing a piano
# tensor(17.8239) a man is a a man
# tensor(17.9618) a man is cooking
# tensor(17.6361) a man is slicing a
# tensor(17.1265) a man is cutting a potato
# tensor(17.2284) a man is swimming in a pool
# tensor(19.0651) a man is flying
# tensor(18.4370) a man is doing with a
# tensor(17.8404) a man is taking on a car
# tensor(18.3356) a man is flying
# tensor(17.4644) a man is riding a horse
# tensor(17.5589) a man is riding a horse
# tensor(16.8957) a man is mixing a bowl
# tensor(17.8326) a woman is eating a woman
# tensor(18.4815) a woman is talking a woman
# tensor(17.1542) a man is talking to a man
# tensor(18.7107) a man is running
# tensor(18.0786) a woman is a woman
# tensor(18.0555) a dog is playing with a
# tensor(17.7687) a man is talking on a computer
# tensor(18.1453) a group of people are running
# tensor(18.0251) a group of people are running
# tensor(18.8189) a panda is playing
# tensor(17.3135) a man is playing with a ball
# tensor(18.2055) a man is putting a
# tensor(17.9362) a cat is playing with a toy
# tensor(18.1894) a man is riding a horse
# tensor(17.8716) a woman is riding a woman
# tensor(17.2966) a man is selling a woman
# tensor(18.1041) a boy is riding a bike
# tensor(18.1231) a man is a man

# %%
# !python evaluate.py -gen results/MSVD/predictions.txt -ref data/MSVD/test_references.txt
# Out:
# Traceback (most recent call last):
#   File "evaluate.py", line 19, in <module>
#     metrics_results = score(load_texts(args.references), load_texts(args.generation))
#   File "/content/drive/My Drive/DACNet/visual_syntactic_embedding_video_captioning/video_description_eval/evaluate.py", line 38, in score
#     score, scores = scorer.compute_score(ref, hypo)
#   File "video_description_eval/coco-caption/pycocoevalcap/meteor/meteor.py", line 39, in compute_score
#     stat = self._stat(res[i][0], gts[i])
#   File "video_description_eval/coco-caption/pycocoevalcap/meteor/meteor.py", line 64, in _stat
#     self.meteor_p.stdin.flush()
# BrokenPipeError: [Errno 32] Broken pipe
# ^C
